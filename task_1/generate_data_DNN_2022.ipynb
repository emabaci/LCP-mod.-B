# %%
import matplotlib.pyplot as plt
import numpy as np

# number of data
N_train = 12800
perc_train = 0.8
N = int( N_train / perc_train)
print(N)
# size of each sample
L = 2
# box size
B = 100

# to generate a folder
# !mkdir DATA
# Out:
# 16000
# mkdir: DATA: File exists

# %%
# posso importare gli header
# %run nonlinear_function.py 

TYPE=1

# random seed for reproducibility --> stesso seed genera stessi dati
np.random.seed(12345)
print(np.random.randint(0,10),np.random.randint(0,10),np.random.randint(0,10))

x,y = (np.random.random((N,2))-0.5)*B, np.zeros(N)
for i in range(N):
    # label data according to a nonlinear function "f"
    y[i] = f(x[i],TYPE)
        
plt.figure(figsize = (8,8))
plt.scatter(x[:,0],x[:,1],c=y)
plt.show

np.savetxt(filename("data_16K",TYPE),x)
np.savetxt(filename("labels_16K",TYPE),y,fmt="%d")
# Out:
# 2 5 1

# %%
print(x[-10:])
# Out:
# [[ 42.61897629 -29.9931934 ]
#  [-31.77676384  -1.24481628]
#  [  2.53014727 -30.34834382]
#  [ 40.41570972  -7.18208644]
#  [-17.50996704 -16.50270985]
#  [-34.81753919  39.61512387]
#  [ -1.38403841  -6.35987724]
#  [  7.62629236  48.07441882]
#  [ 34.2055526  -19.20378904]
#  [-41.29127938  42.18755828]]

# %%
print(x[15990: 16000])
# Out:
# [[ 42.61897629 -29.9931934 ]
#  [-31.77676384  -1.24481628]
#  [  2.53014727 -30.34834382]
#  [ 40.41570972  -7.18208644]
#  [-17.50996704 -16.50270985]
#  [-34.81753919  39.61512387]
#  [ -1.38403841  -6.35987724]
#  [  7.62629236  48.07441882]
#  [ 34.2055526  -19.20378904]
#  [-41.29127938  42.18755828]]
